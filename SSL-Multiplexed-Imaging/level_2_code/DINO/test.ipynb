# %%
import embedding_dataset
from dataclasses import dataclass
from pathlib import Path

@dataclass
class A:
    path_embeddings = Path("/proj/berzelius-2025-315/users/x_dilwi/EMB_patch20/embeddings_epoch_last.npy")
    path_names      = Path("/proj/berzelius-2025-315/users/x_dilwi/EMB_patch20/names_epoch_last.npy")

args = A()
base = embedding_dataset.embedding_dataset(args)

print("LEN:", len(base))
x, name, _ = base[0]
print("item0 type:", type(x), "shape:", getattr(x, "shape", None))
print("name0:", name)
# Out:
# LEN: 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 14
#      11 base = embedding_dataset.embedding_dataset(args)
#      13 print("LEN:", len(base))
# ---> 14 x, name, _ = base[0]
#      15 print("item0 type:", type(x), "shape:", getattr(x, "shape", None))
#      16 print("name0:", name)
#
# ValueError: not enough values to unpack (expected 3, got 2)
